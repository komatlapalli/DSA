# %% [markdown]
# <a href="https://colab.research.google.com/github/komatlapalli/DSA/blob/main/CircularQueue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Queue:
  def __init__(self,maxsize):
    self.items = maxsize * [None]
    self.maxsize = maxsize
    self.top = -1
    self.start = -1

  def __str__(self):
    values = [str(x) for x in self.items]
    return ' '.join(values)
